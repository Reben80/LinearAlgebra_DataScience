# %% [markdown]
# <a href="https://colab.research.google.com/github/Reben80/LinearAlgebra_DataScience/blob/main/Tutorial_Assignment_One_Python_Basics_for_Linear_Algebra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tutorial for Assignment One: Python Basics for Linear Algebra
#
# This notebook provides a guide to help you with 'Assignment One: Python Basics for Linear Algebra'. Follow along and try to understand the concepts and Python syntax used here.
#
# ## 1. Printing and Basic Operations
#
# ### Task 1.1: Print a greeting message introducing yourself.
#
# ```python
# print("Hello, I am [Your Name]. Welcome to Python Basics for Linear Algebra!")
# ```
#
# ### Task 1.2: Perform mathematical operations and print the results.
#
# ```python
# # Addition
# print(45 + 32)
#
# # Subtraction
# print(100 - 56)
#
# # Multiplication
# print(7 * 9)
#
# # Division
# print(144 / 12)
# ```
#
# ## 2. Variables
#
# ### Task 2.1: Store your favorite number and name in variables.
#
# ```python
# fav_num = 7  # Replace 7 with your favorite number
# name = "Rebin"  # Replace 'Rebin' with your name
# ```
#
# ### Task 2.2: Calculate the number of characters in your name.
#
# ```python
# name_length = len(name)
# print(f"My favorite number is {fav_num}, my name is {name}, and my name has {name_length} characters.")
# ```
#
# ## 3. Working with Objects
#
# ### Task 3.1: Create a list of courses.
#
# ```python
# courses = ["Course1", "Course2", "Course3"]  # Replace with your courses
# ```
#
# ### Task 3.2: Print the first course and manipulate a string.
#
# ```python
# # Print the first course
# print(courses[0])
#
# # Working with a string
# phrase = "linear algebra is fun"
# print(phrase.upper())
# ```
#
# ## 4. Modules and Math
#
# ### Task 4.1: Import the math module and use its functions.
#
# ```python
# import math
#
# # Square root
# print(math.sqrt(256))
#
# # Print value of π rounded to 3 decimal places
# print(round(math.pi, 3))
#
# # Converting degrees to radians
# angle_deg = 45
# angle_rad = math.radians(angle_deg)
# print(angle_rad)
# ```
#
# ## 5. Challenge Task: Lists and Math
#
# ### Task 5.1: Working with lists representing matrices.
#
# ```python
# matrices = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
#
# # Print the second element of the second matrix
# print(matrices[1][1])
# ```
#
# ---
#
# Remember to experiment with the code, modify it, and try to understand how each part works. Good luck with your assignment!
